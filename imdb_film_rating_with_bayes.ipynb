# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import math
import scipy.stats as st

# %%
df=pd.read_csv("movies_metadata.csv",low_memory=False)
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df=df[["title","vote_average","vote_count"]]
df.head()
# Out:
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0

# %%
df[df["vote_count"]>900].sort_values("vote_average",ascending=False)
# Out:
#                                   title  vote_average  vote_count
# 40251                        Your Name.           8.5      1030.0
# 834                       The Godfather           8.5      6024.0
# 314            The Shawshank Redemption           8.5      8358.0
# 1152    One Flew Over the Cuckoo's Nest           8.3      3001.0
# 1178             The Godfather: Part II           8.3      3418.0
# ...                                 ...           ...         ...
# 18609  Ghost Rider: Spirit of Vengeance           4.7      1163.0
# 15422                The Last Airbender           4.7      1180.0
# 26563                    Fantastic Four           4.4      2322.0
# 1491                     Batman & Robin           4.2      1447.0
# 28207                 The Boy Next Door           4.1      1034.0
#
# [1240 rows x 3 columns]

# %%
df["vote_count_score"]=MinMaxScaler(feature_range=(1,10)).fit(df[["vote_count"]]).transform(df[["vote_count"]])
df.sort_values("vote_count_score",ascending=False).head(18)
# Out:
# C:\Users\cafer\AppData\Local\Temp\ipykernel_10544\2710105434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["vote_count_score"]=MinMaxScaler(feature_range=(1,10)).fit(df[["vote_count"]]).transform(df[["vote_count"]])
#                                                    title  vote_average  \
# 15480                                          Inception           8.1
# 12481                                    The Dark Knight           8.3
# 14551                                             Avatar           7.2
# 17818                                       The Avengers           7.4
# 26564                                           Deadpool           7.4
# 22879                                       Interstellar           8.1
# ...

# %%
df["average_count_score"]=df["vote_count_score"]*df["vote_count"]
df.sort_values("average_count_score",ascending=False).head(18)
# Out:
# C:\Users\cafer\AppData\Local\Temp\ipykernel_10544\2845821296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["average_count_score"]=df["vote_count_score"]*df["vote_count"]
#                                                    title  vote_average  \
# 15480                                          Inception           8.1
# 12481                                    The Dark Knight           8.3
# 14551                                             Avatar           7.2
# 17818                                       The Avengers           7.4
# 26564                                           Deadpool           7.4
# 22879                                       Interstellar           8.1
# ...

# %%
#IMDB Ağırlıklı Derecelendirme ( IMDB Weighted Rating )
M=2500
C=df["vote_average"].mean()

def weighted_rating(r,v,m,c):
    return (v/(v+m)*r)+(m/(m+v)*c)
df["weighted_rating"]=weighted_rating(df["vote_average"],df["vote_count"],M,C)
df.sort_values("weighted_rating",ascending=False).head()
# Out:
# C:\Users\cafer\AppData\Local\Temp\ipykernel_10544\3211959005.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["weighted_rating"]=weighted_rating(df["vote_average"],df["vote_count"],M,C)
#                           title  vote_average  vote_count  vote_count_score  \
# 12481           The Dark Knight           8.3     12269.0          8.845187
# 314    The Shawshank Redemption           8.5      8358.0          6.344369
# 2843                 Fight Club           8.3      9678.0          7.188419
# 15480                 Inception           8.1     14075.0         10.000000
# 292                Pulp Fiction           8.3      8670.0          6.543872
#
#        average_count_score  weighted_rating
# ...

# %%
#Bayes Ortalama Derecelendirme Puanı ( BAR Score )
def bayesian_average_rating(n, confidence=0.95):
    if sum(n) == 0:
        return 0
    K = len(n)
    z = st.norm.ppf(1 - (1 - confidence) / 2)
    N = sum(n)
    first_part = 0.0
    second_part = 0.0
    for k, n_k in enumerate(n):
        first_part += (k + 1) * (n[k] + 1) / (N + K)
        second_part += (k + 1) * (k + 1) * (n[k] + 1) / (N + K)
    score = first_part - z * math.sqrt((second_part - first_part * first_part) / (N + K + 1))
    return score

# %%
df = pd.read_csv("datasets/imdb_ratings.csv")
df = df.iloc[0:, 1:]


df["bar_score"] = df.apply(lambda x: bayesian_average_rating(x[["one", "two", "three", "four", "five",
                                                                "six", "seven", "eight", "nine", "ten"]]), axis=1)
df.sort_values("bar_score", ascending=False).head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10544\2132425355.py in <module>
# ----> 1 df = pd.read_csv("datasets/imdb_ratings.csv")
#       2 df = df.iloc[0:, 1:]
#       3
#       4
#       5 df["bar_score"] = df.apply(lambda x: bayesian_average_rating(x[["one", "two", "three", "four", "five",
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
